# %%
import pandas as pd

# %%
# Lee el archivo CSV especificando el delimitador principal como ';'
db_candidates = pd.read_csv('DB_Candidates.txt', delimiter=';')

# Selecciona solo las columnas 'Tech Skills' y 'Soft Skills' para aplicar la expresión regular
db_candidates[['Tech Skills', 'Soft Skills']] = db_candidates[['Tech Skills', 'Soft Skills']].apply(lambda x: x.str.split(r'[,]'))

# Ahora db_candidates contiene el DataFrame con los datos correctamente leídos y separados

# %%
db_candidates
# Out:
#        Nombre   Apellido                        Tech Skills  \
# 0        Juan   Bataller            [Python, Pandas, NumPy]
# 1       María      Gómez                             [Java]
# 2       Pedro      López                [JavaScript, React]
# 3       Luisa  Rodríguez                     [PHP, Laravel]
# 4      Carlos   Martínez                           [C++, C]
# 5     Daniela    Sánchez                      [Ruby, Rails]
# 6       Jorge       Ruiz                       [iOS, Swift]
# 7       Lucía       Díaz                          [Android]
# 8       Pablo      Muñoz                 [Node.js, Express]
# 9       Laura    Jiménez       [DevOps, Docker, Kubernetes]
# 10    Micaela    Lorenzo                         [C#, .NET]
# 11     Matías    Álvarez   [Data Science, Machine Learning]
# 12    Luciana     Torres                  [Testing, JMeter]
# 13      Tomás      Pérez             [Blockchain, Solidity]
# 14      Sofía    Giménez               [Product Management]
# 15     Julián   Martínez                     [UX/UI Design]
# 16  Florencia     Suárez                 [Data Engineering]
# 17      Mateo  Rodríguez                        [DevSecOps]
# 18     Jazmín      López               [Mobile Development]
# 19     Thiago      Pérez                        [.NET Core]
# 20   Milagros     García                [Testing, Selenium]
# 21   Benjamín  Fernández        [Product Management, Scrum]
# 22   Agustina      Gómez                   [Python, Django]
# 23  Francisco      López         [Data Science, TensorFlow]
# 24  Valentina      Pérez                  [Frontend, React]
# 25   Santiago     García                 [Backend, Node.js]
# 26   Victoria  Rodríguez             [Mobile, React Native]
# 27      Tadeo   Martínez             [Blockchain, Ethereum]
# 28     Emilia  Fernández                 [Testing, Cypress]
# 29    Benicio     Suárez                  [DevOps, Ansible]
# 30    Candela    Álvarez               [Product Management]
# 31      Dante     Torres                            [UX/UI]
# 32      Bruno    Lorenzo                      [Backend, Go]
# 33    Ariadna      Pérez                 [Frontend, Vue.js]
# 34     Máximo   González                             [Java]
# 35      Juana       Díaz                             [.NET]
# 36       Alan    Sánchez                           [Python]
# 37     Daniel      Pérez                       [JavaScript]
# 38      Paula      López                    [Ruby on Rails]
# 39      Pedro      Gómez                              [iOS]
# 40      Lucas   Martínez                          [Android]
# 41  Valentina  Rodríguez                            [React]
# 42       Maia     García                          [Angular]
# 43     Thiago  Fernández                           [Vue.js]
# 44     Emilia     Suárez                          [Node.js]
# 45      Tomás    Lorenzo                               [Go]
# 46       Juan      Pérez               [Python, SQL, Excel]
# 47      María     García                 [Java, JavaScript]
# 48     Carlos      López                      [C++, Python]
# 49      Laura   Martínez            [HTML, CSS, JavaScript]
# 50      David  Rodríguez  [Python, Pandas, NumPy, Power BI]
# 51        Ana  Fernández              [SQL, Excel, Tableau]
# 52       José    Sánchez                [Java, Python, SQL]
# 53      Sofia       Díaz      [Python, R, Machine Learning]
# 54     Daniel     Torres            [HTML, CSS, JavaScript]
# 55     Andrea       Ruiz                        [C++, Java]
#
#                                        Soft Skills Idioma  \
# 0                   [Trabajo en equipo, Liderazgo]     B2
# 1             [Comunicación, Pensamiento creativo]     C1
# 2                        [Liderazgo, Colaboración]     A2
# 3                       [Organización, Iniciativa]     B1
# 4             [Proactividad, Trabajo bajo presión]     A1
# 5              [Adaptación al cambio, Negociación]     C2
# 6   [Orientación a resultados, Gestión del tiempo]     B2
# 7                       [Iniciativa, Colaboración]     C1
# 8                 [Negociación, Trabajo en equipo]     A1
# 9               [Gestión del tiempo, Comunicación]     C2
# 10          [Resolución de problemas, Creatividad]     B1
# 11                    [Colaboración, Proactividad]     C2
# 12               [Comunicación, Trabajo en equipo]     A2
# 13                [Pensamiento crítico, Liderazgo]     B2
# 14        [Organización, Orientación a resultados]     C1
# 15              [Curiosidad, Adaptación al cambio]     A1
# 16              [Trabajo bajo presión, Iniciativa]     B1
# 17         [Resolución de problemas, Colaboración]     C2
# 18                     [Creatividad, Comunicación]     A2
# 19             [Proactividad, Pensamiento crítico]     B2
# 20                 [Gestión del tiempo, Liderazgo]     C1
# 21                [Negociación, Trabajo en equipo]     A1
# 22                     [Creatividad, Colaboración]     B2
# 23                    [Proactividad, Comunicación]     C1
# 24            [Resolución de problemas, Liderazgo]     A2
# 25             [Pensamiento crítico, Organización]     B1
# 26              [Adaptación al cambio, Iniciativa]     C2
# 27          [Curiosidad, Orientación a resultados]     A1
# 28             [Trabajo bajo presión, Negociación]     B1
# 29   [Resolución de problemas, Gestión del tiempo]     C2
# 30               [Colaboración, Trabajo en equipo]     A2
# 31                     [Comunicación, Creatividad]     B2
# 32                       [Liderazgo, Proactividad]     C1
# 33             [Organización, Pensamiento crítico]     A1
# 34               [Trabajo en equipo, Colaboración]     B2
# 35                     [Comunicación, Creatividad]     C1
# 36                       [Liderazgo, Proactividad]     A2
# 37  [Pensamiento crítico, Resolución de problemas]     B1
# 38              [Adaptación al cambio, Iniciativa]     C2
# 39        [Orientación a resultados, Organización]     B2
# 40      [Trabajo bajo presión, Gestión del tiempo]     A1
# 41                     [Colaboración, Negociación]     B1
# 42                     [Comunicación, Curiosidad ]     C2
# 43                [Liderazgo, Pensamiento crítico]     A2
# 44               [Proactividad, Trabajo en equipo]     C1
# 45                     [Organización, Creatividad]     B2
# 46               [Trabajo en equipo, Proactividad]     B2
# 47         [Comunicación, Resolución de problemas]     C1
# 48                [Liderazgo, Pensamiento crítico]     B1
# 49              [Trabajo en equipo, Adaptabilidad]     A2
# 50            [Liderazgo, Resolución de problemas]     C2
# 51                    [Proactividad, Organización]     B2
# 52               [Trabajo en equipo, Comunicación]     B2
# 53                [Liderazgo, Pensamiento crítico]     C1
# 54        [Adaptabilidad, Resolución de problemas]     A2
# 55                    [Proactividad, Comunicación]     B1
#
#    Disponibilidad Horaria Perfil Psicológico
# 0               Full Time       Extrovertido
# 1               Part Time     Introvertido
# 2       Horario de mañana          Analítico
# 3      Horario vespertino           Creativo
# 4    Flexibilidad Horaria           Racional
# 5               Full Time          Idealista
# 6               Part Time           Realista
# 7       Horario de mañana           Soñador
# 8      Horario vespertino          Altruista
# 9    Flexibilidad Horaria          Servicial
# 10              Full Time          Idealista
# 11              Part Time          Analítico
# 12     Horario vespertino           Realista
# 13      Horario de mañana          Creativo
# 14   Flexibilidad Horaria         Práctico
# 15              Full Time          Soñador
# 16              Part Time         Observador
# 17     Horario vespertino          Idealista
# 18      Horario de mañana         Racional
# 19   Flexibilidad Horaria          Analítico
# 20              Full Time           Realista
# 21              Part Time           Práctico
# 22     Horario vespertino          Idealista
# 23      Horario de mañana        Analítico
# 24              Full Time           Realista
# 25              Part Time           Creativo
# 26   Flexibilidad Horaria           Práctico
# 27     Horario vespertino            Soñador
# 28      Horario de mañana       Observador
# 29              Full Time          Idealista
# 30              Part Time           Racional
# 31     Horario vespertino          Analítico
# 32      Horario de mañana         Realista
# 33              Full Time           Práctico
# 34              Part Time       Extrovertido
# 35              Full Time      Introvertido
# 36     Horario vespertino          Analítico
# 37      Horario de mañana           Creativo
# 38   Flexibilidad Horaria          Idealista
# 39              Part Time           Realista
# 40              Full Time            Soñador
# 41     Horario vespertino           Racional
# 42      Horario de mañana            Ético
# 43   Flexibilidad Horaria          Altruista
# 44              Part Time          Idealista
# 45              Full Time          Analítico
# 46              Full Time          Analítico
# 47              Part Time           Creativo
# 48      Horario de mañana          Analítico
# 49     Horario vespertino           Sociable
# 50   Flexibilidad Horaria          Analítico
# 51              Full Time           Metódico
# 52              Part Time           Creativo
# 53      Horario de mañana          Analítico
# 54     Horario vespertino           Sociable
# 55   Flexibilidad Horaria           Creativo

# %%
db_candidates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Nombre                  56 non-null     object
#  1   Apellido                56 non-null     object
#  2   Tech Skills             56 non-null     object
#  3   Soft Skills             56 non-null     object
#  4   Idioma                  56 non-null     object
#  5   Disponibilidad Horaria  56 non-null     object
#  6   Perfil Psicológico      56 non-null     object
# dtypes: object(7)
# memory usage: 3.2+ KB

# %% [markdown]
# El siguiente código realiza una clasificación y puntuación de los candidatos que se encuentran en db_candidates, de acuerdo a los requerimientos presentes en la solicitud.

# %%
def buscar_candidatos(db_candidates, solicitud):
    # Asignar puntuación por habilidades técnicas
    puntuacion_tecnica = db_candidates['Tech Skills'].apply(lambda x: sum(habilidad in x for habilidad in solicitud['Tech Skills']))
    
    # Asignar puntuación por habilidades blandas
    puntuacion_blanda = db_candidates['Soft Skills'].apply(lambda x: sum(habilidad in x for habilidad in solicitud['Soft Skills']))
    
    # Asignar puntuación por idiomas
    ranking_niveles = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}
    puntuacion_idioma = db_candidates['Idioma'].apply(lambda x: ranking_niveles[x] >= ranking_niveles[solicitud['Idioma'][0]])
    
    # Asignar puntuación por disponibilidad horaria
    puntuacion_horaria = db_candidates['Disponibilidad Horaria'].apply(lambda x: sum(disponibilidad in x for disponibilidad in solicitud['Disponibilidad Horaria']))

    # Asignar puntuación por perfil psicológico
    puntuacion_perfil = db_candidates['Perfil Psicológico'].apply(lambda x: sum(perfil in x for perfil in solicitud['Perfil Psicológico']))
    
    # Calcular puntuación total
    puntuacion_total = puntuacion_tecnica + puntuacion_blanda + puntuacion_idioma + puntuacion_horaria + puntuacion_perfil
    
    return puntuacion_total

# %%
solicitud = {
    'Tech Skills': ['Data Science', 'Python'],
    'Soft Skills': ['Comunicación', 'Trabajo en equipo'],
    'Idioma': ['C1'],
    'Disponibilidad Horaria': ['Full Time'],
    'Perfil Psicológico': ['Creativo']
}

puntuacion = buscar_candidatos(db_candidates, solicitud)
candidatos_seleccionados = puntuacion.nlargest(5)
print(candidatos_seleccionados)
# Out:
# 52    4
# 0     3
# 23    3
# 35    3
# 46    3
# dtype: int64

# %%
puntuacion = buscar_candidatos(db_candidates, solicitud)
puntuacion.name = 'puntuacion'
candidatos_seleccionados = puntuacion.nlargest(5).index

# Convertir el índice en una columna normal
db_candidates_indexed = db_candidates.reset_index()

# Unir las series `puntuacion` y `db_candidates_indexed`
db_candidates_indexed = db_candidates_indexed.join(puntuacion)

# Seleccionar las filas deseadas
listado_candidatos_selecc = db_candidates_indexed.set_index(['index']).loc[candidatos_seleccionados].set_index(['Apellido', 'Nombre'])

print(listado_candidatos_selecc)
# Out:
#                                    Tech Skills  \
# Apellido Nombre
# Sánchez  José              [Java, Python, SQL]
# Bataller Juan          [Python, Pandas, NumPy]
# López    Francisco  [Data Science, TensorFlow]
# Díaz     Juana                          [.NET]
# Pérez    Juan             [Python, SQL, Excel]
#
#                                           Soft Skills Idioma  \
# Apellido Nombre
# Sánchez  José       [Trabajo en equipo, Comunicación]     B2
# Bataller Juan          [Trabajo en equipo, Liderazgo]     B2
# López    Francisco       [Proactividad, Comunicación]     C1
# Díaz     Juana            [Comunicación, Creatividad]     C1
# Pérez    Juan       [Trabajo en equipo, Proactividad]     B2
#
#                    Disponibilidad Horaria Perfil Psicológico  puntuacion
# Apellido Nombre
# Sánchez  José                   Part Time           Creativo           4
# Bataller Juan                   Full Time       Extrovertido           3
# López    Francisco      Horario de mañana        Analítico             3
# Díaz     Juana                  Full Time      Introvertido            3
# Pérez    Juan                   Full Time          Analítico           3

# %%
listado_candidatos_selecc
# Out:
#                                    Tech Skills  \
# Apellido Nombre
# Sánchez  José              [Java, Python, SQL]
# Bataller Juan          [Python, Pandas, NumPy]
# López    Francisco  [Data Science, TensorFlow]
# Díaz     Juana                          [.NET]
# Pérez    Juan             [Python, SQL, Excel]
#
#                                           Soft Skills Idioma  \
# Apellido Nombre
# Sánchez  José       [Trabajo en equipo, Comunicación]     B2
# Bataller Juan          [Trabajo en equipo, Liderazgo]     B2
# López    Francisco       [Proactividad, Comunicación]     C1
# Díaz     Juana            [Comunicación, Creatividad]     C1
# Pérez    Juan       [Trabajo en equipo, Proactividad]     B2
#
#                    Disponibilidad Horaria Perfil Psicológico  puntuacion
# Apellido Nombre
# Sánchez  José                   Part Time           Creativo           4
# Bataller Juan                   Full Time       Extrovertido           3
# López    Francisco      Horario de mañana        Analítico             3
# Díaz     Juana                  Full Time      Introvertido            3
# Pérez    Juan                   Full Time          Analítico           3

# %%
print('Requerimientos de la Solicitud', solicitud)
# Out:
# Requerimientos de la Solicitud {'Tech Skills': ['Data Science', 'Python'], 'Soft Skills': ['Comunicación', 'Trabajo en equipo'], 'Idioma': ['C1'], 'Disponibilidad Horaria': ['Full Time'], 'Perfil Psicológico': ['Creativo']}

# %%
solicitud
# Out:
# {'Tech Skills': ['Data Science', 'Python'],
#  'Soft Skills': ['Comunicación', 'Trabajo en equipo'],
#  'Idioma': ['C1'],
#  'Disponibilidad Horaria': ['Full Time'],
#  'Perfil Psicológico': ['Creativo']}

# %% [markdown]
# La siguiente versión restringe la elección de los candidatos a aquellos que al menos cumplen con uno de los requerimientos de Tech Skills, y cuyo nivel de idioma no difiere en menos de 2 valores respecto del nivel requerido. Caso contrario, el candidato no es tenido en cuenta aunque cumpla con el resto de los requisitos.

# %%
def buscar_candidatos(db_candidates, solicitud):
    # Verificar si los candidatos cumplen con al menos una habilidad técnica
    cumple_tecnica = db_candidates['Tech Skills'].apply(lambda x: any(habilidad in x for habilidad in solicitud['Tech Skills']))
    
    # Verificar si los candidatos cumplen con el nivel de idioma dentro del rango permitido
    ranking_niveles = {'A1': 1, 'A2': 2, 'B1': 3, 'B2': 4, 'C1': 5, 'C2': 6}
    cumple_idioma = db_candidates['Idioma'].apply(lambda x: abs(ranking_niveles[x] - ranking_niveles[solicitud['Idioma'][0]]) <= 2)
    
    # Filtrar candidatos válidos que cumplen con al menos una habilidad técnica y tienen un nivel de idioma dentro del rango
    candidatos_validos = db_candidates[cumple_tecnica & cumple_idioma]

    if candidatos_validos.empty:
        return None  # No hay candidatos que cumplan con los requisitos

    # Asignar puntuación por habilidades técnicas
    puntuacion_tecnica = db_candidates['Tech Skills'].apply(lambda x: sum(habilidad in x for habilidad in solicitud['Tech Skills']))

    # Asignar puntuación por habilidades blandas
    puntuacion_blanda = candidatos_validos['Soft Skills'].apply(lambda x: sum(habilidad in x for habilidad in solicitud['Soft Skills']))
    
    # Asignar puntuación por idiomas
    puntuacion_idioma = db_candidates['Idioma'].apply(lambda x: ranking_niveles[x] >= ranking_niveles[solicitud['Idioma'][0]])

    # Asignar puntuación por disponibilidad horaria
    puntuacion_horaria = candidatos_validos['Disponibilidad Horaria'].apply(lambda x: sum(disponibilidad in x for disponibilidad in solicitud['Disponibilidad Horaria']))

    # Asignar puntuación por perfil psicológico
    puntuacion_perfil = candidatos_validos['Perfil Psicológico'].apply(lambda x: sum(perfil in x for perfil in solicitud['Perfil Psicológico']))
    
    # Calcular puntuación total considerando las habilidades técnicas y de idioma
    # puntuacion_total = (cumple_tecnica.astype(int) + cumple_idioma.astype(int)) * (puntuacion_tecnica + puntuacion_blanda + puntuacion_idioma + puntuacion_horaria + puntuacion_perfil)
    puntuacion_total = (puntuacion_tecnica + puntuacion_blanda + puntuacion_idioma + puntuacion_horaria + puntuacion_perfil)
    return puntuacion_total

# %%
puntuacion = buscar_candidatos(db_candidates, solicitud)
puntuacion.name = 'puntuacion'
candidatos_seleccionados = puntuacion.nlargest(5).index

# Convertir el índice en una columna normal
db_candidates_indexed = db_candidates.reset_index()

# Unir las series `puntuacion` y `db_candidates_indexed`
db_candidates_indexed = db_candidates_indexed.join(puntuacion)

# Seleccionar las filas deseadas
listado_candidatos_selecc = db_candidates_indexed.set_index(['index']).loc[candidatos_seleccionados].set_index(['Apellido', 'Nombre'])

print(listado_candidatos_selecc)
# Out:
#                                          Tech Skills  \
# Apellido Nombre
# Sánchez  José                    [Java, Python, SQL]
# Bataller Juan                [Python, Pandas, NumPy]
# López    Francisco        [Data Science, TensorFlow]
# Pérez    Juan                   [Python, SQL, Excel]
# Álvarez  Matías     [Data Science, Machine Learning]
#
#                                           Soft Skills Idioma  \
# Apellido Nombre
# Sánchez  José       [Trabajo en equipo, Comunicación]     B2
# Bataller Juan          [Trabajo en equipo, Liderazgo]     B2
# López    Francisco       [Proactividad, Comunicación]     C1
# Pérez    Juan       [Trabajo en equipo, Proactividad]     B2
# Álvarez  Matías          [Colaboración, Proactividad]     C2
#
#                    Disponibilidad Horaria Perfil Psicológico  puntuacion
# Apellido Nombre
# Sánchez  José                   Part Time           Creativo         4.0
# Bataller Juan                   Full Time       Extrovertido         3.0
# López    Francisco      Horario de mañana        Analítico           3.0
# Pérez    Juan                   Full Time          Analítico         3.0
# Álvarez  Matías                 Part Time          Analítico         2.0

# %%
listado_candidatos_selecc
# Out:
#                                          Tech Skills  \
# Apellido Nombre
# Sánchez  José                    [Java, Python, SQL]
# Bataller Juan                [Python, Pandas, NumPy]
# López    Francisco        [Data Science, TensorFlow]
# Pérez    Juan                   [Python, SQL, Excel]
# Álvarez  Matías     [Data Science, Machine Learning]
#
#                                           Soft Skills Idioma  \
# Apellido Nombre
# Sánchez  José       [Trabajo en equipo, Comunicación]     B2
# Bataller Juan          [Trabajo en equipo, Liderazgo]     B2
# López    Francisco       [Proactividad, Comunicación]     C1
# Pérez    Juan       [Trabajo en equipo, Proactividad]     B2
# Álvarez  Matías          [Colaboración, Proactividad]     C2
#
#                    Disponibilidad Horaria Perfil Psicológico  puntuacion
# Apellido Nombre
# Sánchez  José                   Part Time           Creativo         4.0
# Bataller Juan                   Full Time       Extrovertido         3.0
# López    Francisco      Horario de mañana        Analítico           3.0
# Pérez    Juan                   Full Time          Analítico         3.0
# Álvarez  Matías                 Part Time          Analítico         2.0

# %%
solicitud
# Out:
# {'Tech Skills': ['Data Science', 'Python'],
#  'Soft Skills': ['Comunicación', 'Trabajo en equipo'],
#  'Idioma': ['C1'],
#  'Disponibilidad Horaria': ['Full Time'],
#  'Perfil Psicológico': ['Creativo']}
